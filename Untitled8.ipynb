# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshirathod136/sakshi-s-first-phython/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to check whether a number is odd or even

num = 19

print("Given number:", num)

if num % 2 == 0:
    print("The number is Even")
else:
    print("The number is Odd")
# Out:
# Given number: 19
# The number is Odd
